# %% [markdown]
# <a href="https://colab.research.google.com/github/C-HARRIETH/WK9-IP/blob/main/Moringa_DS_Core_W9_Independent_Project_II_2021_04_Python_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SPAM ANALYSIS**

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### a) Specifying the Data Analytic Question

# %% [markdown]
# > Determine whether an e-mail is spam or not.

# %% [markdown]
# ### b) Defining the Metric for Success

# %% [markdown]
# Model that is at least 85% accurate.

# %% [markdown]
# ### c) Understanding the context

# %% [markdown]
# > Over the recent past, businesses and even hackers have been sending spam messages to people for various reasons and it could place a person in danger. Hence the need to create a model that can accurately predict whether the mail is spam or not even before the user opens the email.

# %% [markdown]
# ### d) Recording the Experimental Design

# %% [markdown]
# The experimental design taken is Independent measures done by random allocation.

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# The data provided is highly relevant to the research and is pre-processed.

# %% [markdown]
# ## 2. Reading the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading csv files
data =  pd.read_csv('spambase.data', sep=",")

# %%
with open('/content/spambase.names') as f:
    print(f.read())
# Out:
# | SPAM E-MAIL DATABASE ATTRIBUTES (in .names format)
# |
# | 48 continuous real [0,100] attributes of type word_freq_WORD
# | = percentage of words in the e-mail that match WORD,
# | i.e. 100 * (number of times the WORD appears in the e-mail) /
# | total number of words in e-mail.  A "word" in this case is any
# | string of alphanumeric characters bounded by non-alphanumeric
# | characters or end-of-string.
# |
# | 6 continuous real [0,100] attributes of type char_freq_CHAR
# | = percentage of characters in the e-mail that match CHAR,
# | i.e. 100 * (number of CHAR occurences) / total characters in e-mail
# |
# | 1 continuous real [1,...] attribute of type capital_run_length_average
# | = average length of uninterrupted sequences of capital letters
# |
# | 1 continuous integer [1,...] attribute of type capital_run_length_longest
# | = length of longest uninterrupted sequence of capital letters
# |
# | 1 continuous integer [1,...] attribute of type capital_run_length_total
# ...

# %%
with open('/content/spambase.DOCUMENTATION') as f:
    print(f.read())
# Out:
# 1. Title:  SPAM E-mail Database
#
# 2. Sources:
#    (a) Creators: Mark Hopkins, Erik Reeber, George Forman, Jaap Suermondt
#         Hewlett-Packard Labs, 1501 Page Mill Rd., Palo Alto, CA 94304
#    (b) Donor: George Forman (gforman at nospam hpl.hp.com)  650-857-7835
#    (c) Generated: June-July 1999
#
# 3. Past Usage:
#    (a) Hewlett-Packard Internal-only Technical Report. External forthcoming.
#    (b) Determine whether a given email is spam or not.
#    (c) ~7% misclassification error.
#        False positives (marking good mail as spam) are very undesirable.
#        If we insist on zero false positives in the training/testing set,
#        20-25% of the spam passed through the filter.
#
# 4. Relevant Information:
#         The "spam" concept is diverse: advertisements for products/web
#         sites, make money fast schemes, chain letters, pornography...
# 	Our collection of spam e-mails came from our postmaster and
# ...

# %% [markdown]
# ## 3. Checking the Data

# %%
# No. of records in dataset
data.shape
# Out:
# (4600, 58)

# %%
data.head()
# Out:
#       0  0.64  0.64.1  0.1  0.32   0.2  ...   0.43   0.44  3.756   61   278  1
# 0  0.21  0.28    0.50  0.0  0.14  0.28  ...  0.180  0.048  5.114  101  1028  1
# 1  0.06  0.00    0.71  0.0  1.23  0.19  ...  0.184  0.010  9.821  485  2259  1
# 2  0.00  0.00    0.00  0.0  0.63  0.00  ...  0.000  0.000  3.537   40   191  1
# 3  0.00  0.00    0.00  0.0  0.63  0.00  ...  0.000  0.000  3.537   40   191  1
# 4  0.00  0.00    0.00  0.0  1.85  0.00  ...  0.000  0.000  3.000   15    54  1
#
# [5 rows x 58 columns]

# %%
# Checking whether each column has an appropriate datatype
#

data.dtypes
# Out:
# 0         float64
# 0.64      float64
# 0.64.1    float64
# 0.1       float64
# 0.32      float64
# 0.2       float64
# 0.3       float64
# 0.4       float64
# 0.5       float64
# 0.6       float64
# 0.7       float64
# 0.64.2    float64
# 0.8       float64
# 0.9       float64
# 0.10      float64
# 0.32.1    float64
# 0.11      float64
# 1.29      float64
# 1.93      float64
# 0.12      float64
# 0.96      float64
# 0.13      float64
# 0.14      float64
# 0.15      float64
# 0.16      float64
# 0.17      float64
# 0.18      float64
# 0.19      float64
# 0.20      float64
# 0.21      float64
# 0.22      float64
# 0.23      float64
# 0.24      float64
# 0.25      float64
# 0.26      float64
# 0.27      float64
# 0.28      float64
# 0.29      float64
# 0.30      float64
# 0.31      float64
# 0.32.2    float64
# 0.33      float64
# 0.34      float64
# 0.35      float64
# 0.36      float64
# 0.37      float64
# 0.38      float64
# 0.39      float64
# 0.40      float64
# 0.41      float64
# ...

# %% [markdown]
# ## 4. Tidying the Dataset

# %%
# Transforming Col 1 to category
data['1'] = data['1'].astype('category')

# %% [markdown]
# The data is pre-processed and a little was needed to be done in order to model.

# %% [markdown]
# ## 5. Exploratory Analysis

# %%
spam= data['1'].value_counts()
spam.plot.pie(autopct="%.1f%%")
plt.title('Spam distribution')
plt.show()

# %%
data.describe()
# Out:
#                  0         0.64  ...           61           278
# count  4600.000000  4600.000000  ...  4600.000000   4600.000000
# mean      0.104576     0.212922  ...    52.170870    283.290435
# std       0.305387     1.290700  ...   194.912453    606.413764
# min       0.000000     0.000000  ...     1.000000      1.000000
# 25%       0.000000     0.000000  ...     6.000000     35.000000
# 50%       0.000000     0.000000  ...    15.000000     95.000000
# 75%       0.000000     0.000000  ...    43.000000    265.250000
# max       4.540000    14.280000  ...  9989.000000  15841.000000
#
# [8 rows x 57 columns]

# %% [markdown]
# ## 6. Implementing the Solution

# %%
# Splitting the dataset

X = data.drop("1",axis=1)
y = data["1"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=69)

# %%
# Fitting the model
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB(alpha=0).fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)

# %%
# Prediction
predicted = model.predict(X_test)
print(np.mean(predicted == y_test))
# Out:
# 0.7945652173913044

# %% [markdown]
# Accuracy Analysis according to train and test splits.
#
# | Split(%) | Accuracy|
# |:---------|--------:|
# |80-20  | 78% |
# | 70-30 | 78% |
# | 60-40 | 79% |

# %% [markdown]
# Setting a low alpha value(0), smoothing parameter does not affect the accuracy of the model

# %% [markdown]
# ## 7. Follow up questions

# %% [markdown]
# ### Did we have the right data?

# %% [markdown]
# Data provided was not sufficient for the research. It had its limitations. The .document file had the column names but did not specify which column was which. This limited further optimization procedures.
